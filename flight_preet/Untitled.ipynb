# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('flights_price_predictor_preet.csv')
del df['Unnamed: 0']

# %%
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left   price
# 0           Mumbai  Economy      2.17          1  5953.0
# 1           Mumbai  Economy      2.33          1  5953.0
# 2           Mumbai  Economy      2.17          1  5956.0
# 3           Mumbai  Economy      2.25          1  5955.0
# 4           Mumbai  Economy      2.33          1  5955.0

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df['departure_time'])
le.classes_

# %%
le.transform(df['departure_time'])
# le.inverse_transform([0, 0, 1, 2])
print(le.inverse_transform(df['departure_time']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 le.transform(df['departure_time'])
#       2 # le.inverse_transform([0, 0, 1, 2])
# ----> 3 print(le.inverse_transform(df['departure_time']))
#
# File ~/opt/anaconda3/envs/sem2/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:161, in LabelEncoder.inverse_transform(self, y)
#     159 diff = np.setdiff1d(y, np.arange(len(self.classes_)))
#     160 if len(diff):
# --> 161     raise ValueError("y contains previously unseen labels: %s" % str(diff))
#     162 y = np.asarray(y)
#     163 return self.classes_[y]
#
# ValueError: y contains previously unseen labels: ['Afternoon' 'Early_Morning' 'Evening' 'Late_Night' 'Morning' 'Night']

# %%
le.classes_
# Out:
# array(['Afternoon', 'Early_Morning', 'Evening', 'Late_Night', 'Morning',
#        'Night'], dtype=object)

# %%
le = preprocessing.LabelEncoder()
le.fit(["paris", "paris", "tokyo", "amsterdam"])
list(le.classes_)
le.transform(["tokyo", "tokyo", "paris"])
list(le.inverse_transform([2, 2, 1]))
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left    price
# 0                Mumbai   Economy      2.17          1   5953.0
# 1                Mumbai   Economy      2.33          1   5953.0
# 2                Mumbai   Economy      2.17          1   5956.0
# 3                Mumbai   Economy      2.25          1   5955.0
# 4                Mumbai   Economy      2.33          1   5955.0
# ...                 ...       ...       ...        ...      ...
# 300148        Hyderabad  Business     10.08         49  69265.0
# 300149        Hyderabad  Business     10.42         49  77105.0
# 300150        Hyderabad  Business     13.83         49  79099.0
# 300151        Hyderabad  Business     10.00         49  81585.0
# 300152        Hyderabad  Business     10.08         49  81585.0
#
# [300153 rows x 11 columns]

# %%
df
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left    price
# 0                Mumbai   Economy      2.17          1   5953.0
# 1                Mumbai   Economy      2.33          1   5953.0
# 2                Mumbai   Economy      2.17          1   5956.0
# 3                Mumbai   Economy      2.25          1   5955.0
# 4                Mumbai   Economy      2.33          1   5955.0
# ...                 ...       ...       ...        ...      ...
# 300148        Hyderabad  Business     10.08         49  69265.0
# 300149        Hyderabad  Business     10.42         49  77105.0
# 300150        Hyderabad  Business     13.83         49  79099.0
# 300151        Hyderabad  Business     10.00         49  81585.0
# 300152        Hyderabad  Business     10.08         49  81585.0
#
# [300153 rows x 11 columns]

# %%
cor=df.corr()
plt.plot(cor)
# Out:
# [<matplotlib.lines.Line2D at 0x7fa7b8c10160>,
#  <matplotlib.lines.Line2D at 0x7fa7b8cdfbe0>,
#  <matplotlib.lines.Line2D at 0x7fa7b8cdf280>]
